# %% [markdown]
# <a href="https://colab.research.google.com/github/lucianedecastro/exerciciosDataPythonSenai/blob/main/CBSurf_DesempenhoWesleyLeite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício Adaptado com a Base de Informações de Desempenho do Atleta Wesley Leite - Dream Tour - CBSurf

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_desempenho=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Desempenho CBSurf.xlsx')
display(df_desempenho)
# Out:
#     Ano         Categoria                      Etapa  Rounds  Ondas  \
# 0  2023  Pro - Dream Tour          1ª - Xangrilla/RS       2    NaN
# 1  2023  Pro - Dream Tour           2ª - Garopaba/SC       2   16.0
# 2  2023  Pro - Dream Tour            3ª - Floripa/SC       5   40.0
# 3  2023  Pro - Dream Tour             4ª - Maceio/AL       4   46.0
# 4  2023  Pro - Dream Tour           5ª - Salvador/BA       3   35.0
# 5  2023  Pro - Dream Tour                6ª - Rio/RJ       6   50.0
# 6  2024  Pro - Dream Tour  1ª - Porto de Galinhas/PE       2   21.0
# 7  2024  Pro - Dream Tour         2ª - Vila Velha/ES       6   60.0
#
#    Melhor Somatório Posição Ranking
# 0              9.94     17º     25º
# 1             14.57     17º     25º
# 2             14.17      3º     25º
# 3             14.00      5º     25º
# 4             11.66      9º     25º
# 5             14.33      2º      3º
# 6             12.20     17º     22º
# 7             12.67      1º      2º

# %%
fig=sns.displot(data=df_desempenho,x='Melhor Somatório',kind='ecdf')
plt.show(fig)

# %%
grafi_linha=sns.lineplot(df_desempenho,x='Etapa',y='Rounds',color='red')#lineplot comando monta gráfico de linhas
plt.xticks(rotation=90)
plt.show(grafi_linha)

# %%
grafi_linha=sns.lineplot(df_desempenho,x='Etapa',y='Posição',color='red')#lineplot comando monta gráfico de linhas
plt.xticks(rotation=90)
plt.show(grafi_linha)

# %%
fig=sns.displot(data=df_desempenho,x='Ano',kind='kde')
plt.show(fig)

# %%
plt.figure(figsize=(20,4)) #Gráfco Plot = Gráfico de Linha
plt.plot(df_desempenho['Ano'],df_desempenho['Posição'],label='Xapa',color='g',ls='--',lw='2')#Date é o eixo x e Close é o eixo y - comando label monta a legenda 'NYA' -
#color é o comando para definir a cor da linha - ls comando para tipo de linha e lw comando para espessura da linha
plt.legend(loc=2,fontsize=18) #plt.legend comando pra plotar a legenda. sem essa linha, a legenda não aparece
plt.ylabel('Melhor Somatório')
plt.xlabel('Ano')
plt.title('Gráfico de Desempenho no Dream Tour - Wesley Leite')
#plt.axis(xmin='2012',xmax='2024')
#plt.xticks(['2012','2014','2016','2018','2020','2022','2024'])
plt.xticks(rotation=90)
plt.show()#.show para visualizar gráfico
